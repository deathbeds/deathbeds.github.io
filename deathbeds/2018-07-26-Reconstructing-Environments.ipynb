# %% [markdown]
# # How might we include `noarch: python` packages in a conda constructor?
# Many of the pure-python packages on `conda-forge` are `python: noarch`, but the constructor project [isn't interested](https://github.com/conda/constructor/issues/96) in pursuing compatibility with them at this time for various, understandable reasons.
#
# This is an exploration of packaging a non-trivial application (JupyterHub) as a constructor, initially started with [zero2one](https://github.com/bollwyvl/zero2one).

# %%
import subprocess, tarfile, tempfile, json, shutil, copy
from pathlib import Path

import jinja2
from ruamel_yaml import safe_dump, safe_load

from constructor.construct import parse
from constructor.conda_interface import cc_platform

# %%
def run(args):
    print("Running", "\n\t", " ".join(args))
    proc = subprocess.Popen(args, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    for line in iter(proc.stdout.readline, b''):
        print(line.decode('utf-8').rstrip())

# %% [markdown]
# # Build a `construct.yaml`

# %%
Path("construct").mkdir(exist_ok=True)

# %%
# %%file construct/construct.yaml
# {% set version = "0.9.0" %}
#
# name: JupyterHubOne
# version: {{ version }}
#
# install_in_dependency_order: True
#
# channels:
# - https://conda.anaconda.org/conda-forge/
# - https://repo.anaconda.com/pkgs/main/
#
# post_install: post_install.sh
#
# specs:
# # this drives our version
# - jupyterhub =={{ version }}
# # always use most recent conda
# - conda
# # use node LTS for stability
# - nodejs >=8,<9
# - python >=3.6,<3.7
# - ncurses <6.1
# Out:
# Writing construct/construct.yaml

# %%
# %%file construct/post_install.sh
# #!/usr/bin/env bash
# echo "OK!"
# Out:
# Writing construct/post_install.sh

# %% [markdown]
# # Build a (broken) installer

# %%
run(["constructor",
     "construct",
     "--verbose",
     "--cache-dir", "./construct-cache"])
# Out:
# Running
# 	 constructor construct --verbose --cache-dir ./construct-cache
# platform: linux-64
# conda packages download: /home/weg/Documents/projects/constructorthopaedic/construct-cache/linux-64
# specs: ['jupyterhub ==0.9.0', 'conda', 'nodejs >=8,<9', 'python >=3.6,<3.7', 'ncurses <6.1']
#
#
# name: JupyterHubOne
# version: 0.9.0
# cache download location: /home/weg/Documents/projects/constructorthopaedic/construct-cache/linux-64
# platform: linux-64
# number of package: 66
#     defaults::python-3.6.5-hc3d631a_2
#     conda-forge::ca-certificates-2018.4.16-0
#     defaults::conda-env-2.6.0-h36134e3_1
#     defaults::libgcc-ng-7.2.0-hdf63c60_3
#     defaults::libstdcxx-ng-7.2.0-hdf63c60_3
#     defaults::libffi-3.2.1-hd88cf55_4
#     defaults::ncurses-6.0-h9df7e31_2
#     defaults::nodejs-8.11.1-hf484d3e_0
#     defaults::openssl-1.0.2o-h20670df_0
#     defaults::tk-8.6.7-hc745277_3
#     defaults::xz-5.2.4-h14c3975_4
#     defaults::yaml-0.1.7-had09818_2
#     conda-forge::zlib-1.2.11-h470a237_3
#     conda-forge::configurable-http-proxy-3.1.0-node8_1
#     defaults::libedit-3.1-heed3624_0
#     defaults::libssh2-1.8.0-h9cfc8f7_4
#     defaults::readline-7.0-ha6073c6_4
#     defaults::libcurl-7.60.0-h1ad7b7a_0
#     defaults::sqlite-3.23.1-he433501_0
#     conda-forge::appdirs-1.4.3-py_1
#     defaults::asn1crypto-0.24.0-py36_0
#     conda-forge::async_generator-1.9-0
#     conda-forge::attrs-18.1.0-py_1
#     defaults::certifi-2018.4.16-py36_0
#     defaults::chardet-3.0.4-py36h0f667ec_1
#     conda-forge::constantly-15.1.0-py_0
#     defaults::decorator-4.3.0-py36_0
#     defaults::idna-2.7-py36_0
#     defaults::incremental-17.5.0-py36hff7e2ee_0
#     defaults::ipython_genutils-0.2.0-py36hb52b0d5_0
#     defaults::markupsafe-1.0-py36hd9260cd_1
#     conda-forge::pamela-0.3.0-py36_0
#     conda-forge::pyasn1-0.4.3-py_0
#     defaults::pycosat-0.6.3-py36h0a5515d_0
#     defaults::pycparser-2.18-py36hf9f622e_1
#     defaults::pycurl-7.43.0.2-py36hb7f436b_0
#     conda-forge::pysocks-1.6.8-py36_1
#     defaults::python-editor-1.0.3-py36h928c527_0
#     conda-forge::python-oauth2-1.0.1-py36_0
#     defaults::ruamel_yaml-0.15.40-py36h14c3975_2
#     defaults::six-1.11.0-py36h372c433_1
#     defaults::sqlalchemy-1.2.8-py36h14c3975_0
#     defaults::tornado-5.0.2-py36_0
#     conda-forge::zope.interface-4.5.0-py36h470a237_0
#     defaults::automat-0.7.0-py36_0
#     defaults::cffi-1.11.5-py36h9745a5d_0
#     defaults::hyperlink-18.0.0-py36_0
#     defaults::mako-1.0.7-py36h0727276_0
#     defaults::pyasn1-modules-0.2.1-py36hc893066_0
#     conda-forge::pyhamcrest-1.9.0-py36_1
#     conda-forge::python-dateutil-2.7.3-py_0
#     defaults::setuptools-39.2.0-py36_0
#     defaults::traitlets-4.3.2-py36h674d592_0
#     defaults::alembic-0.9.9-py36_0
#     defaults::cryptography-2.2.2-py36h14c3975_0
#     defaults::jinja2-2.10-py36ha16c418_0
#     defaults::wheel-0.31.1-py36_0
#     defaults::pip-10.0.1-py36_0
#     defaults::pyopenssl-18.0.0-py36_0
#     conda-forge::service_identity-17.0.0-py_0
#     conda-forge::urllib3-1.23-py36_0
#     defaults::requests-2.19.1-py36_0
#     conda-forge::twisted-18.4.0-py36h470a237_0
#     conda-forge::conda-4.5.4-py36_0
#     conda-forge::prometheus_client-0.2.0-py36_0
#     conda-forge::jupyterhub-0.9.0-py36_0
#
# fetching: python-3.6.5-hc3d631a_2.tar.bz2
# fetching: ca-certificates-2018.4.16-0.tar.bz2
# fetching: conda-env-2.6.0-h36134e3_1.tar.bz2
# fetching: libgcc-ng-7.2.0-hdf63c60_3.tar.bz2
# fetching: libstdcxx-ng-7.2.0-hdf63c60_3.tar.bz2
# fetching: libffi-3.2.1-hd88cf55_4.tar.bz2
# fetching: ncurses-6.0-h9df7e31_2.tar.bz2
# fetching: nodejs-8.11.1-hf484d3e_0.tar.bz2
# fetching: openssl-1.0.2o-h20670df_0.tar.bz2
# fetching: tk-8.6.7-hc745277_3.tar.bz2
# fetching: xz-5.2.4-h14c3975_4.tar.bz2
# fetching: yaml-0.1.7-had09818_2.tar.bz2
# fetching: zlib-1.2.11-h470a237_3.tar.bz2
# fetching: configurable-http-proxy-3.1.0-node8_1.tar.bz2
# fetching: libedit-3.1-heed3624_0.tar.bz2
# fetching: libssh2-1.8.0-h9cfc8f7_4.tar.bz2
# fetching: readline-7.0-ha6073c6_4.tar.bz2
# fetching: libcurl-7.60.0-h1ad7b7a_0.tar.bz2
# fetching: sqlite-3.23.1-he433501_0.tar.bz2
# fetching: appdirs-1.4.3-py_1.tar.bz2
# fetching: asn1crypto-0.24.0-py36_0.tar.bz2
# fetching: async_generator-1.9-0.tar.bz2
# fetching: attrs-18.1.0-py_1.tar.bz2
# fetching: certifi-2018.4.16-py36_0.tar.bz2
# fetching: chardet-3.0.4-py36h0f667ec_1.tar.bz2
# fetching: constantly-15.1.0-py_0.tar.bz2
# fetching: decorator-4.3.0-py36_0.tar.bz2
# fetching: idna-2.7-py36_0.tar.bz2
# fetching: incremental-17.5.0-py36hff7e2ee_0.tar.bz2
# fetching: ipython_genutils-0.2.0-py36hb52b0d5_0.tar.bz2
# fetching: markupsafe-1.0-py36hd9260cd_1.tar.bz2
# fetching: pamela-0.3.0-py36_0.tar.bz2
# fetching: pyasn1-0.4.3-py_0.tar.bz2
# fetching: pycosat-0.6.3-py36h0a5515d_0.tar.bz2
# fetching: pycparser-2.18-py36hf9f622e_1.tar.bz2
# fetching: pycurl-7.43.0.2-py36hb7f436b_0.tar.bz2
# fetching: pysocks-1.6.8-py36_1.tar.bz2
# fetching: python-editor-1.0.3-py36h928c527_0.tar.bz2
# fetching: python-oauth2-1.0.1-py36_0.tar.bz2
# fetching: ruamel_yaml-0.15.40-py36h14c3975_2.tar.bz2
# fetching: six-1.11.0-py36h372c433_1.tar.bz2
# fetching: sqlalchemy-1.2.8-py36h14c3975_0.tar.bz2
# fetching: tornado-5.0.2-py36_0.tar.bz2
# fetching: zope.interface-4.5.0-py36h470a237_0.tar.bz2
# fetching: automat-0.7.0-py36_0.tar.bz2
# fetching: cffi-1.11.5-py36h9745a5d_0.tar.bz2
# fetching: hyperlink-18.0.0-py36_0.tar.bz2
# fetching: mako-1.0.7-py36h0727276_0.tar.bz2
# fetching: pyasn1-modules-0.2.1-py36hc893066_0.tar.bz2
# fetching: pyhamcrest-1.9.0-py36_1.tar.bz2
# fetching: python-dateutil-2.7.3-py_0.tar.bz2
# fetching: setuptools-39.2.0-py36_0.tar.bz2
# fetching: traitlets-4.3.2-py36h674d592_0.tar.bz2
# fetching: alembic-0.9.9-py36_0.tar.bz2
# fetching: cryptography-2.2.2-py36h14c3975_0.tar.bz2
# fetching: jinja2-2.10-py36ha16c418_0.tar.bz2
# fetching: wheel-0.31.1-py36_0.tar.bz2
# fetching: pip-10.0.1-py36_0.tar.bz2
# fetching: pyopenssl-18.0.0-py36_0.tar.bz2
# fetching: service_identity-17.0.0-py_0.tar.bz2
# fetching: urllib3-1.23-py36_0.tar.bz2
# fetching: requests-2.19.1-py36_0.tar.bz2
# fetching: twisted-18.4.0-py36h470a237_0.tar.bz2
# fetching: conda-4.5.4-py36_0.tar.bz2
# fetching: prometheus_client-0.2.0-py36_0.tar.bz2
# fetching: jupyterhub-0.9.0-py36_0.tar.bz2
# Checking for duplicate files ...
# Warning: Files 'share/terminfo/P/P7', 'share/terminfo/p/p7' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P8', 'share/terminfo/p/p8' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p8-w', 'share/terminfo/P/P8-W' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/h/hp2621a', 'share/terminfo/h/hp2621A' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/2/2621A', 'share/terminfo/2/2621a' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P9-8', 'share/terminfo/p/p9-8' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P14-M', 'share/terminfo/p/p14-m' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p12-m', 'share/terminfo/P/P12-M' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/h/hp70092a', 'share/terminfo/h/hp70092A' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p12-m-w', 'share/terminfo/P/P12-M-W' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P9-8-W', 'share/terminfo/p/p9-8-w' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p14-m-w', 'share/terminfo/P/P14-M-W' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P4', 'share/terminfo/p/p4' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P5', 'share/terminfo/p/p5' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/E/Eterm', 'share/terminfo/e/eterm' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P9-W', 'share/terminfo/p/p9-w' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P12-W', 'share/terminfo/p/p12-w' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p14-w', 'share/terminfo/P/P14-W' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P9', 'share/terminfo/p/p9' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P12', 'share/terminfo/p/p12' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p14', 'share/terminfo/P/P14' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/E/Eterm-color', 'share/terminfo/e/eterm-color' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/l/lft-pc850', 'share/terminfo/L/LFT-PC850' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/n/ncrvt100wpp', 'share/terminfo/N/NCRVT100WPP' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/n/ncr260vt300wpp', 'share/terminfo/N/NCR260VT300WPP' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'ssl/man/man3/MDC2.3', 'ssl/man/man3/mdc2.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/rc4.3', 'ssl/man/man3/RC4.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/MD5.3', 'ssl/man/man3/md5.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/BN_print.3', 'ssl/man/man3/bn_print.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/hmac.3', 'ssl/man/man3/HMAC.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/PEM.3', 'ssl/man/man3/pem.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/SSL.3', 'ssl/man/man3/ssl.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Reading: /home/weg/Documents/projects/constructorthopaedic/envs/_build/lib/python3.6/site-packages/constructor/header.sh
# Successfully created '/home/weg/Documents/projects/constructorthopaedic/JupyterHubOne-0.9.0-Linux-x86_64.sh'.

# %% [markdown]
# # Determine what was `noarch: python`

# %%
cached_packages = list((Path("construct-cache") / cc_platform).glob("*.bz2"))

noarch = {}

for tarpath in cached_packages:
    with tarfile.open(tarpath, mode="r:bz2") as tf:
        index = json.loads(tf.extractfile("info/index.json").read().decode("utf-8"))
        if index.get("noarch") == "python":
            noarch[index["name"]] = tarpath
print(noarch)
# Out:
# {'python-dateutil': PosixPath('construct-cache/linux-64/python-dateutil-2.7.3-py_0.tar.bz2'), 'async_generator': PosixPath('construct-cache/linux-64/async_generator-1.9-0.tar.bz2'), 'pyasn1': PosixPath('construct-cache/linux-64/pyasn1-0.4.3-py_0.tar.bz2'), 'attrs': PosixPath('construct-cache/linux-64/attrs-18.1.0-py_1.tar.bz2'), 'appdirs': PosixPath('construct-cache/linux-64/appdirs-1.4.3-py_1.tar.bz2'), 'constantly': PosixPath('construct-cache/linux-64/constantly-15.1.0-py_0.tar.bz2'), 'service_identity': PosixPath('construct-cache/linux-64/service_identity-17.0.0-py_0.tar.bz2')}

# %% [markdown]
# # Build a conda package containing those tarballs

# %%
original_construct = parse("./construct/construct.yaml", cc_platform)
original_construct
# Out:
# {'name': 'JupyterHubOne',
#  'version': '0.9.0',
#  'install_in_dependency_order': True,
#  'channels': ['https://conda.anaconda.org/conda-forge/',
#   'https://repo.anaconda.com/pkgs/main/'],
#  'post_install': 'post_install.sh',
#  'specs': ['jupyterhub ==0.9.0',
#   'conda',
#   'nodejs >=8,<9',
#   'python >=3.6,<3.7',
#   'ncurses <6.1']}

# %%
recipe_yaml = jinja2.Template("""
package:
    name: {{ package_name }}
    version: {{ version }}

source:
    path: ../packages

build:
    number: 0
    skip: true  # [not {{ cc_platform|replace("-", "") }}]
    script:
    - mkdir -p $PREFIX/share/{{ package_name }}/{{ cc_platform }}
    - cp *.bz2 $PREFIX/share/{{ package_name }}/{{ cc_platform }}/
    - conda index $PREFIX/share/{{ package_name }}/{{ cc_platform }}/
    - mkdir -p $PREFIX/share/{{ package_name }}/noarch
    - conda index $PREFIX/share/{{ package_name }}/noarch

requirements:
    run: []

about:
    summary: a conda channel of extra packages for {{ name }}
    license: Other
""").render(
    cc_platform=cc_platform,
    **original_construct,
    package_name="{}-extras".format(original_construct["name"].lower())
)
print(recipe_yaml)
# Out:
# package:
#     name: jupyterhubone-extras
#     version: 0.9.0
#
# source:
#     path: ../packages
#
# build:
#     number: 0
#     skip: true  # [not linux64]
#     script:
#     - mkdir -p $PREFIX/share/jupyterhubone-extras/linux-64
#     - cp *.bz2 $PREFIX/share/jupyterhubone-extras/linux-64/
#     - conda index $PREFIX/share/jupyterhubone-extras/linux-64/
#     - mkdir -p $PREFIX/share/jupyterhubone-extras/noarch
#     - conda index $PREFIX/share/jupyterhubone-extras/noarch
#
# requirements:
#     run: []
#
# about:
#     summary: a conda channel of extra packages for JupyterHubOne
#     license: Other

# %%
recipe = safe_load(recipe_yaml)
recipe
# Out:
# {'package': {'name': 'jupyterhubone-extras', 'version': '0.9.0'},
#  'source': {'path': '../packages'},
#  'build': {'number': 0,
#   'skip': True,
#   'script': ['mkdir -p $PREFIX/share/jupyterhubone-extras/linux-64',
#    'cp *.bz2 $PREFIX/share/jupyterhubone-extras/linux-64/',
#    'conda index $PREFIX/share/jupyterhubone-extras/linux-64/',
#    'mkdir -p $PREFIX/share/jupyterhubone-extras/noarch',
#    'conda index $PREFIX/share/jupyterhubone-extras/noarch']},
#  'requirements': {'run': []},
#  'about': {'summary': 'a conda channel of extra packages for JupyterHubOne',
#   'license': 'Other'}}

# %%
out_packages = (Path(".") / "conda-bld")
#shutil.rmtree(out_packages)
out_packages.mkdir(exist_ok=True)

# %%
with tempfile.TemporaryDirectory() as td:
    tdp = Path(td)
    recipe_dir = tdp / "recipe"
    recipe_dir.mkdir()
    (recipe_dir / "meta.yaml").write_text(recipe_yaml)
    package_dir = tdp / "packages"
    package_dir.mkdir()
    for pkg in noarch.values():
        shutil.copy2(str(pkg), package_dir)
    run([
        "conda-build",
        "--output-folder", str(out_packages),
        str(recipe_dir)
    ])
# Out:
# Running
# 	 conda-build --output-folder conda-bld /tmp/tmpjbgz99lx/recipe
# Adding in variants from internal_defaults
# INFO:conda_build.variants:Adding in variants from internal_defaults
# Attempting to finalize metadata for jupyterhubone-extras
# INFO:conda_build.metadata:Attempting to finalize metadata for jupyterhubone-extras
# updating: python-dateutil-2.7.3-py_0.tar.bz2
# updating: async_generator-1.9-0.tar.bz2
# updating: pyasn1-0.4.3-py_0.tar.bz2
# updating: attrs-18.1.0-py_1.tar.bz2
# updating: appdirs-1.4.3-py_1.tar.bz2
# updating: constantly-15.1.0-py_0.tar.bz2
# updating: service_identity-17.0.0-py_0.tar.bz2
# BUILD START: ['jupyterhubone-extras-0.9.0-0.tar.bz2']
# Copying /tmp/tmpjbgz99lx/packages to /home/weg/Documents/projects/constructorthopaedic/envs/_build/conda-bld/jupyterhubone-extras_1530241615144/work
# source tree in: /home/weg/Documents/projects/constructorthopaedic/envs/_build/conda-bld/jupyterhubone-extras_1530241615144/work
#
# Resource usage statistics from building jupyterhubone-extras:
#    Process count: 1
#    CPU time: unavailable
#    Memory: 3.1M
#    Disk usage: 348B
#    Time elapsed: 0:00:02.1
#
# Packaging jupyterhubone-extras
# INFO:conda_build.build:Packaging jupyterhubone-extras
# Packaging jupyterhubone-extras-0.9.0-0
# INFO:conda_build.build:Packaging jupyterhubone-extras-0.9.0-0
# number of files: 19
# Fixing permissions
# updating: jupyterhubone-extras-0.9.0-0.tar.bz2
# TEST START: conda-bld/linux-64/jupyterhubone-extras-0.9.0-0.tar.bz2
# Updating index at /home/weg/Documents/projects/constructorthopaedic/conda-bld/linux-64 to make package installable with dependencies
# INFO:conda_build.build:Updating index at /home/weg/Documents/projects/constructorthopaedic/conda-bld/linux-64 to make package installable with dependencies
# Updating index at /home/weg/Documents/projects/constructorthopaedic/conda-bld/noarch to make package installable with dependencies
# INFO:conda_build.build:Updating index at /home/weg/Documents/projects/constructorthopaedic/conda-bld/noarch to make package installable with dependencies
# Adding in variants from /tmp/tmpc806s9dj/info/recipe/conda_build_config.yaml
# INFO:conda_build.variants:Adding in variants from /tmp/tmpc806s9dj/info/recipe/conda_build_config.yaml
# Nothing to test for: conda-bld/linux-64/jupyterhubone-extras-0.9.0-0.tar.bz2
# Renaming work directory,  /home/weg/Documents/projects/constructorthopaedic/envs/_build/conda-bld/jupyterhubone-extras_1530241615144/work  to  /home/weg/Documents/projects/constructorthopaedic/envs/_build/conda-bld/jupyterhubone-extras_1530241615144/work_moved_jupyterhubone-extras-0.9.0-0_linux-64_main_build_loop
# # Automatic uploading is disabled
# # If you want to upload package(s) to anaconda.org later, type:
#
# anaconda upload conda-bld/linux-64/jupyterhubone-extras-0.9.0-0.tar.bz2
#
# # To have conda build upload to anaconda.org automatically, use
# # $ conda config --set anaconda_upload yes
#
# anaconda_upload is not set.  Not uploading wheels: []
# ####################################################################################
# Resource usage summary:
#
# Total time: 0:00:04.7
# CPU usage: sys=0:00:00.0, user=0:00:00.0
# Maximum memory usage observed: 3.1M
# Total disk usage observed (not including envs): 348B
#
#
# ####################################################################################
# Source and build intermediates have been left in /home/weg/Documents/projects/constructorthopaedic/envs/_build/conda-bld.
# There are currently 3 accumulated.
# To remove them, you can run the ```conda build purge``` command

# %% [markdown]
# # Build a (less broken) Installer

# %%
new_construct = copy.deepcopy(original_construct)
new_construct["name"] += "Fixed"
new_construct.setdefault("exclude", []).extend(list(noarch))
new_construct.setdefault("channels", []).append(out_packages.resolve().as_uri())
new_construct["specs"].append(recipe["package"]["name"])
if new_construct.get("post_install") is None:
    new_construct["post_install"] = "install_extras.sh"
new_construct
# Out:
# {'name': 'JupyterHubOneFixed',
#  'version': '0.9.0',
#  'install_in_dependency_order': True,
#  'channels': ['https://conda.anaconda.org/conda-forge/',
#   'https://repo.anaconda.com/pkgs/main/',
#   'file:///home/weg/Documents/projects/constructorthopaedic/conda-bld'],
#  'post_install': 'post_install.sh',
#  'specs': ['jupyterhub ==0.9.0',
#   'conda',
#   'nodejs >=8,<9',
#   'python >=3.6,<3.7',
#   'ncurses <6.1',
#   'jupyterhubone-extras'],
#  'exclude': ['python-dateutil',
#   'async_generator',
#   'pyasn1',
#   'attrs',
#   'appdirs',
#   'constantly',
#   'service_identity']}

# %%
shebang = "#!/usr/bin/env bash"

# %%
install_script = jinja2.Template("""
set -x
${PREFIX}/bin/conda install \
    --yes \
    --prefix ${PREFIX} \
    --offline \
    --force \
    --channel file://${PREFIX}/share/{{ package["name"] }} \
    {{ packages }}
""").render(**recipe, cc_platform=cc_platform, packages=" ".join(list(noarch.keys()))).strip()

# %%
with tempfile.TemporaryDirectory() as td:
    tdp = Path(td)
    shutil.copytree(Path("construct"), tdp / "construct")
    tdp_ctx = tdp / "construct"
    (tdp_ctx / "construct.yaml").write_text(
        safe_dump(new_construct, default_flow_style=False)
    )
    if original_construct.get("post_install"):
        script_path = tdp_ctx / original_construct.get("post_install")
        script_lines = script_path.read_text().split("\n")
        if script_lines[0].startswith("#!"):
            script_lines = [
                script_lines[0],
                install_script,
                *script_lines[1:]
            ]
        else:
            script_lines = [
                shebang,
                install_script, 
                *script_lines
            ]
        script_path.write_text("\n".join(script_lines))
    else:
        (tdp_ctx / new_construct["post_install"]).write_text("\n".join([
            shebang,
            install_script
        ]))
    run(["constructor",
         str(tdp_ctx),
         "--verbose",
         "--cache-dir", "./construct-cache"])
# Out:
# Running
# 	 constructor /tmp/tmpgav80zyn/construct --verbose --cache-dir ./construct-cache
# platform: linux-64
# conda packages download: /home/weg/Documents/projects/constructorthopaedic/construct-cache/linux-64
# specs: ['jupyterhub ==0.9.0', 'conda', 'nodejs >=8,<9', 'python >=3.6,<3.7', 'ncurses <6.1', 'jupyterhubone-extras']
#
#
# name: JupyterHubOneFixed
# version: 0.9.0
# cache download location: /home/weg/Documents/projects/constructorthopaedic/construct-cache/linux-64
# platform: linux-64
# number of package: 60
#     defaults::python-3.6.5-hc3d631a_2
#     conda-forge::ca-certificates-2018.4.16-0
#     defaults::conda-env-2.6.0-h36134e3_1
#     file:///home/weg/Documents/projects/constructorthopaedic/conda-bld::jupyterhubone-extras-0.9.0-0
#     defaults::libgcc-ng-7.2.0-hdf63c60_3
#     defaults::libstdcxx-ng-7.2.0-hdf63c60_3
#     defaults::libffi-3.2.1-hd88cf55_4
#     defaults::ncurses-6.0-h9df7e31_2
#     defaults::nodejs-8.11.1-hf484d3e_0
#     defaults::openssl-1.0.2o-h20670df_0
#     defaults::tk-8.6.7-hc745277_3
#     defaults::xz-5.2.4-h14c3975_4
#     defaults::yaml-0.1.7-had09818_2
#     conda-forge::zlib-1.2.11-h470a237_3
#     conda-forge::configurable-http-proxy-3.1.0-node8_1
#     defaults::libedit-3.1-heed3624_0
#     defaults::libssh2-1.8.0-h9cfc8f7_4
#     defaults::readline-7.0-ha6073c6_4
#     defaults::libcurl-7.60.0-h1ad7b7a_0
#     defaults::sqlite-3.23.1-he433501_0
#     defaults::asn1crypto-0.24.0-py36_0
#     defaults::certifi-2018.4.16-py36_0
#     defaults::chardet-3.0.4-py36h0f667ec_1
#     defaults::decorator-4.3.0-py36_0
#     defaults::idna-2.7-py36_0
#     defaults::incremental-17.5.0-py36hff7e2ee_0
#     defaults::ipython_genutils-0.2.0-py36hb52b0d5_0
#     defaults::markupsafe-1.0-py36hd9260cd_1
#     conda-forge::pamela-0.3.0-py36_0
#     defaults::pycosat-0.6.3-py36h0a5515d_0
#     defaults::pycparser-2.18-py36hf9f622e_1
#     defaults::pycurl-7.43.0.2-py36hb7f436b_0
#     conda-forge::pysocks-1.6.8-py36_1
#     defaults::python-editor-1.0.3-py36h928c527_0
#     conda-forge::python-oauth2-1.0.1-py36_0
#     defaults::ruamel_yaml-0.15.40-py36h14c3975_2
#     defaults::six-1.11.0-py36h372c433_1
#     defaults::sqlalchemy-1.2.8-py36h14c3975_0
#     defaults::tornado-5.0.2-py36_0
#     conda-forge::zope.interface-4.5.0-py36h470a237_0
#     defaults::automat-0.7.0-py36_0
#     defaults::cffi-1.11.5-py36h9745a5d_0
#     defaults::hyperlink-18.0.0-py36_0
#     defaults::mako-1.0.7-py36h0727276_0
#     defaults::pyasn1-modules-0.2.1-py36hc893066_0
#     conda-forge::pyhamcrest-1.9.0-py36_1
#     defaults::setuptools-39.2.0-py36_0
#     defaults::traitlets-4.3.2-py36h674d592_0
#     defaults::alembic-0.9.9-py36_0
#     defaults::cryptography-2.2.2-py36h14c3975_0
#     defaults::jinja2-2.10-py36ha16c418_0
#     defaults::wheel-0.31.1-py36_0
#     defaults::pip-10.0.1-py36_0
#     defaults::pyopenssl-18.0.0-py36_0
#     conda-forge::urllib3-1.23-py36_0
#     defaults::requests-2.19.1-py36_0
#     conda-forge::twisted-18.4.0-py36h470a237_0
#     conda-forge::conda-4.5.4-py36_0
#     conda-forge::prometheus_client-0.2.0-py36_0
#     conda-forge::jupyterhub-0.9.0-py36_0
#
# fetching: jupyterhubone-extras-0.9.0-0.tar.bz2
# Checking for duplicate files ...
# Warning: Files 'share/terminfo/P/P7', 'share/terminfo/p/p7' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P8', 'share/terminfo/p/p8' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P8-W', 'share/terminfo/p/p8-w' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/h/hp2621a', 'share/terminfo/h/hp2621A' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/2/2621A', 'share/terminfo/2/2621a' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p9-8', 'share/terminfo/P/P9-8' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P14-M', 'share/terminfo/p/p14-m' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P12-M', 'share/terminfo/p/p12-m' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/h/hp70092a', 'share/terminfo/h/hp70092A' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p12-m-w', 'share/terminfo/P/P12-M-W' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p9-8-w', 'share/terminfo/P/P9-8-W' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P14-M-W', 'share/terminfo/p/p14-m-w' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p4', 'share/terminfo/P/P4' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P5', 'share/terminfo/p/p5' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/E/Eterm', 'share/terminfo/e/eterm' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P9-W', 'share/terminfo/p/p9-w' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/P/P12-W', 'share/terminfo/p/p12-w' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p14-w', 'share/terminfo/P/P14-W' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p9', 'share/terminfo/P/P9' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p12', 'share/terminfo/P/P12' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/p/p14', 'share/terminfo/P/P14' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/E/Eterm-color', 'share/terminfo/e/eterm-color' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/l/lft-pc850', 'share/terminfo/L/LFT-PC850' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/N/NCRVT100WPP', 'share/terminfo/n/ncrvt100wpp' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'share/terminfo/n/ncr260vt300wpp', 'share/terminfo/N/NCR260VT300WPP' found in the package(s): ncurses-6.0-h9df7e31_2.tar.bz2
# Warning: Files 'ssl/man/man3/MDC2.3', 'ssl/man/man3/mdc2.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/rc4.3', 'ssl/man/man3/RC4.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/md5.3', 'ssl/man/man3/MD5.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/bn_print.3', 'ssl/man/man3/BN_print.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/hmac.3', 'ssl/man/man3/HMAC.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/PEM.3', 'ssl/man/man3/pem.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Warning: Files 'ssl/man/man3/SSL.3', 'ssl/man/man3/ssl.3' found in the package(s): openssl-1.0.2o-h20670df_0.tar.bz2
# Reading: /home/weg/Documents/projects/constructorthopaedic/envs/_build/lib/python3.6/site-packages/constructor/header.sh
# Successfully created '/home/weg/Documents/projects/constructorthopaedic/JupyterHubOneFixed-0.9.0-Linux-x86_64.sh'.

# %% [markdown]
# # Test the constructor in docker
# > TODO: generalize the pattern by tracking the output installer

# %%
Path("docker_test").mkdir(exist_ok=True)

# %%
# %%file docker_test/Dockerfile
# FROM centos:7
# RUN yum install -y -qq bzip2
# COPY JupyterHubOneFixed-0.9.0-Linux-x86_64.sh /tmp/
# RUN bash /tmp/JupyterHubOneFixed-0.9.0-Linux-x86_64.sh -fbp /opt/jupyterhub
# COPY startup.sh /tmp/
# RUN chmod +x /tmp/startup.sh
# CMD ["/tmp/startup.sh"]
# Out:
# Writing docker_test/Dockerfile

# %%
# %%file docker_test/startup.sh
# #!/usr/bin/env bash
# set -ex
# source /opt/jupyterhub/bin/activate /opt/jupyterhub
# env | sort
# jupyterhub
# Out:
# Writing docker_test/startup.sh

# %%
# %%file docker-compose.yml
# version: "3"
# services:
#   hub:
#     build:
#       context: docker_test
#     ports:
#       - 8081:8081
#       - 8000:8000
# Out:
# Writing docker-compose.yml

# %%
# !cp JupyterHubOneFixed-0.9.0-Linux-x86_64.sh docker_test/

# %%
run(["docker-compose", "build"])
# Out:
# Running
# 	 docker-compose build
# Building hub
# Step 1/7 : FROM centos:7
#  ---> 49f7960eb7e4
# Step 2/7 : RUN yum install -y -qq bzip2
#  ---> Using cache
#  ---> d947fef0225d
# Step 3/7 : COPY JupyterHubOneFixed-0.9.0-Linux-x86_64.sh /tmp/
#  ---> 9d6430c11850
# Removing intermediate container 72e1ae6d9e12
# Step 4/7 : RUN bash /tmp/JupyterHubOneFixed-0.9.0-Linux-x86_64.sh -fbp /opt/jupyterhub
#  ---> Running in 092da11385d0
#
# PREFIX=/opt/jupyterhub
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.4.16-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: jupyterhubone-extras-0.9.0-0 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.0-h9df7e31_2 ...
# installing: nodejs-8.11.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-h470a237_3 ...
# installing: configurable-http-proxy-3.1.0-node8_1 ...
# installing: libedit-3.1-heed3624_0 ...
# installing: libssh2-1.8.0-h9cfc8f7_4 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: libcurl-7.60.0-h1ad7b7a_0 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: decorator-4.3.0-py36_0 ...
# installing: idna-2.7-py36_0 ...
# installing: incremental-17.5.0-py36hff7e2ee_0 ...
# installing: ipython_genutils-0.2.0-py36hb52b0d5_0 ...
# installing: markupsafe-1.0-py36hd9260cd_1 ...
# installing: pamela-0.3.0-py36_0 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pycurl-7.43.0.2-py36hb7f436b_0 ...
# installing: pysocks-1.6.8-py36_1 ...
# installing: python-editor-1.0.3-py36h928c527_0 ...
# installing: python-oauth2-1.0.1-py36_0 ...
# installing: ruamel_yaml-0.15.40-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: sqlalchemy-1.2.8-py36h14c3975_0 ...
# installing: tornado-5.0.2-py36_0 ...
# installing: zope.interface-4.5.0-py36h470a237_0 ...
# installing: automat-0.7.0-py36_0 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: hyperlink-18.0.0-py36_0 ...
# installing: mako-1.0.7-py36h0727276_0 ...
# installing: pyasn1-modules-0.2.1-py36hc893066_0 ...
# installing: pyhamcrest-1.9.0-py36_1 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: traitlets-4.3.2-py36h674d592_0 ...
# installing: alembic-0.9.9-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: jinja2-2.10-py36ha16c418_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.23-py36_0 ...
# installing: requests-2.19.1-py36_0 ...
# installing: twisted-18.4.0-py36h470a237_0 ...
# installing: conda-4.5.4-py36_0 ...
# installing: prometheus_client-0.2.0-py36_0 ...
# installing: jupyterhub-0.9.0-py36_0 ...
# + /opt/jupyterhub/bin/conda install --prefix /opt/jupyterhub --offline --force --channel file:///opt/jupyterhub/share/jupyterhubone-extras python-dateutil async_generator pyasn1 attrs appdirs constantly service_identity
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /opt/jupyterhub
#
#   added / updated specs:
#     - appdirs
#     - async_generator
#     - attrs
#     - constantly
#     - pyasn1
#     - python-dateutil
#     - service_identity
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pyasn1-0.4.3               |             py_0          46 KB  file:///opt/jupyterhub/share/jupyterhubone-extras
#     async_generator-1.9        |                0          17 KB  file:///opt/jupyterhub/share/jupyterhubone-extras
#     appdirs-1.4.3              |             py_1          11 KB  file:///opt/jupyterhub/share/jupyterhubone-extras
#     service_identity-17.0.0    |             py_0          11 KB  file:///opt/jupyterhub/share/jupyterhubone-extras
#     constantly-15.1.0          |             py_0           9 KB  file:///opt/jupyterhub/share/jupyterhubone-extras
#     attrs-18.1.0               |             py_1          25 KB  file:///opt/jupyterhub/share/jupyterhubone-extras
#     python-dateutil-2.7.3      |             py_0         202 KB  file:///opt/jupyterhub/share/jupyterhubone-extras
#     ------------------------------------------------------------
#                                            Total:         320 KB
#
# The following NEW packages will be INSTALLED:
#
#     appdirs:          1.4.3-py_1  file:///opt/jupyterhub/share/jupyterhubone-extras
#     async_generator:  1.9-0       file:///opt/jupyterhub/share/jupyterhubone-extras
#     attrs:            18.1.0-py_1 file:///opt/jupyterhub/share/jupyterhubone-extras
#     constantly:       15.1.0-py_0 file:///opt/jupyterhub/share/jupyterhubone-extras
#     pyasn1:           0.4.3-py_0  file:///opt/jupyterhub/share/jupyterhubone-extras
#     python-dateutil:  2.7.3-py_0  file:///opt/jupyterhub/share/jupyterhubone-extras
#     service_identity: 17.0.0-py_0 file:///opt/jupyterhub/share/jupyterhubone-extras
#
# Proceed ([y]/n)?
# pyasn1-0.4.3         |   46 KB | ########## | 100%
# async_generator-1.9  |   17 KB | ########## | 100%
# appdirs-1.4.3        |   11 KB | ########## | 100%
# service_identity-17. |   11 KB | ########## | 100%
# constantly-15.1.0    |    9 KB | ########## | 100%
# attrs-18.1.0         |   25 KB | ########## | 100%
# python-dateutil-2.7. |  202 KB | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# OK!
# + echo 'OK!'
# installation finished.
#  ---> 71fde4d6f20e
# Removing intermediate container 092da11385d0
# Step 5/7 : COPY startup.sh /tmp/
#  ---> 428c8e4b45ce
# Removing intermediate container 96ff3a53361a
# Step 6/7 : RUN chmod +x /tmp/startup.sh
#  ---> Running in 21ee13e70e7d
#
#  ---> 5f26a3e086ec
# Removing intermediate container 21ee13e70e7d
# Step 7/7 : CMD /tmp/startup.sh
#  ---> Running in 7145befbf049
#  ---> 1691c74ac670
# Removing intermediate container 7145befbf049
# Successfully built 1691c74ac670

# %%
run(["docker-compose", "up"])
# Out:
# Running
# 	 docker-compose up
# Recreating constructorthopaedic_hub_1 ...
# Attaching to constructorthopaedic_hub_1
# hub_1  | + source /opt/jupyterhub/bin/activate /opt/jupyterhub
# hub_1  | ++ _CONDA_ROOT=/opt/jupyterhub
# hub_1  | ++ . /opt/jupyterhub/etc/profile.d/conda.sh
# hub_1  | +++ _CONDA_EXE=/opt/jupyterhub/bin/conda
# hub_1  | +++ _CONDA_ROOT=/opt/jupyterhub
# hub_1  | +++ _conda_set_vars
# hub_1  | +++ '[' -n x ']'
# hub_1  | +++ _CONDA_SHELL_FLAVOR=bash
# hub_1  | +++ '[' -z x ']'
# hub_1  | +++ '[' -z '' ']'
# hub_1  | +++ PS1=
# hub_1  | +++ '[' -z '' ']'
# hub_1  | +++ export CONDA_SHLVL=0
# hub_1  | +++ CONDA_SHLVL=0
# hub_1  | ++ _conda_activate /opt/jupyterhub
# hub_1  | ++ '[' -n '' ']'
# hub_1  | ++ local ask_conda
# hub_1  | +++ PS1=
# hub_1  | +++ /opt/jupyterhub/bin/conda shell.posix activate /opt/jupyterhub
# hub_1  | ++ ask_conda='PS1='\''(base) '\''
# hub_1  | \export CONDA_DEFAULT_ENV='\''base'\''
# hub_1  | \export CONDA_EXE='\''/opt/jupyterhub/bin/conda'\''
# hub_1  | \export CONDA_PREFIX='\''/opt/jupyterhub'\''
# hub_1  | \export CONDA_PROMPT_MODIFIER='\''(base) '\''
# hub_1  | \export CONDA_PYTHON_EXE='\''/opt/jupyterhub/bin/python'\''
# hub_1  | \export CONDA_SHLVL='\''1'\''
# hub_1  | \export PATH='\''/opt/jupyterhub/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin'\'''
# hub_1  | ++ eval 'PS1='\''(base) '\''
# hub_1  | \export CONDA_DEFAULT_ENV='\''base'\''
# hub_1  | \export CONDA_EXE='\''/opt/jupyterhub/bin/conda'\''
# hub_1  | \export CONDA_PREFIX='\''/opt/jupyterhub'\''
# hub_1  | \export CONDA_PROMPT_MODIFIER='\''(base) '\''
# hub_1  | \export CONDA_PYTHON_EXE='\''/opt/jupyterhub/bin/python'\''
# hub_1  | \export CONDA_SHLVL='\''1'\''
# hub_1  | \export PATH='\''/opt/jupyterhub/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin'\'''
# hub_1  | +++ PS1='(base) '
# hub_1  | +++ export CONDA_DEFAULT_ENV=base
# hub_1  | +++ CONDA_DEFAULT_ENV=base
# hub_1  | +++ export CONDA_EXE=/opt/jupyterhub/bin/conda
# hub_1  | +++ CONDA_EXE=/opt/jupyterhub/bin/conda
# hub_1  | +++ export CONDA_PREFIX=/opt/jupyterhub
# hub_1  | +++ CONDA_PREFIX=/opt/jupyterhub
# hub_1  | +++ export 'CONDA_PROMPT_MODIFIER=(base) '
# hub_1  | +++ CONDA_PROMPT_MODIFIER='(base) '
# hub_1  | +++ export CONDA_PYTHON_EXE=/opt/jupyterhub/bin/python
# hub_1  | +++ CONDA_PYTHON_EXE=/opt/jupyterhub/bin/python
# hub_1  | +++ export CONDA_SHLVL=1
# hub_1  | +++ CONDA_SHLVL=1
# hub_1  | +++ export PATH=/opt/jupyterhub/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# hub_1  | +++ PATH=/opt/jupyterhub/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# hub_1  | ++ _conda_hashr
# hub_1  | ++ case "$_CONDA_SHELL_FLAVOR" in
# hub_1  | ++ hash -r
# hub_1  | + sort
# hub_1  | + env
# hub_1  | CONDA_DEFAULT_ENV=base
# hub_1  | CONDA_EXE=/opt/jupyterhub/bin/conda
# hub_1  | CONDA_PREFIX=/opt/jupyterhub
# hub_1  | CONDA_PROMPT_MODIFIER=(base)
# hub_1  | CONDA_PYTHON_EXE=/opt/jupyterhub/bin/python
# hub_1  | CONDA_SHLVL=1
# hub_1  | HOME=/root
# hub_1  | HOSTNAME=355bb8861f0d
# hub_1  | PATH=/opt/jupyterhub/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# hub_1  | PWD=/
# hub_1  | SHLVL=1
# hub_1  | _=/usr/bin/env
# hub_1  | + jupyterhub
# hub_1  | [I 2018-06-29 03:08:14.491 JupyterHub app:1656] Using Authenticator: jupyterhub.auth.PAMAuthenticator-0.9.0
# hub_1  | [I 2018-06-29 03:08:14.491 JupyterHub app:1656] Using Spawner: jupyterhub.spawner.LocalProcessSpawner-0.9.0
# hub_1  | [I 2018-06-29 03:08:14.494 JupyterHub app:1053] Writing cookie_secret to /jupyterhub_cookie_secret
# hub_1  | [I 2018-06-29 03:08:14.514 alembic.runtime.migration migration:117] Context impl SQLiteImpl.
# hub_1  | [I 2018-06-29 03:08:14.515 alembic.runtime.migration migration:122] Will assume non-transactional DDL.
# hub_1  | [I 2018-06-29 03:08:14.560 alembic.runtime.migration migration:327] Running stamp_revision  -> 896818069c98
# hub_1  | [I 2018-06-29 03:08:15.138 JupyterHub proxy:429] Generating new CONFIGPROXY_AUTH_TOKEN
# hub_1  | [W 2018-06-29 03:08:15.141 JupyterHub app:1160] No admin users, admin interface will be unavailable.
# hub_1  | [W 2018-06-29 03:08:15.141 JupyterHub app:1161] Add any administrative users to `c.Authenticator.admin_users` in config.
# hub_1  | [I 2018-06-29 03:08:15.141 JupyterHub app:1188] Not using whitelist. Any authenticated user will be allowed.
# hub_1  | [I 2018-06-29 03:08:15.174 JupyterHub app:1838] Hub API listening on http://127.0.0.1:8081/hub/
# hub_1  | [W 2018-06-29 03:08:15.175 JupyterHub proxy:481] Running JupyterHub without SSL.  I hope there is SSL termination happening somewhere else...
# hub_1  | [I 2018-06-29 03:08:15.175 JupyterHub proxy:483] Starting proxy @ http://:8000
# hub_1  | 03:08:15.593 - info: [ConfigProxy] Proxying http://*:8000 to (no default)
# hub_1  | 03:08:15.595 - info: [ConfigProxy] Proxy API at http://127.0.0.1:8001/api/routes
# hub_1  | 03:08:16.046 - info: [ConfigProxy] 200 GET /api/routes
# hub_1  | [I 2018-06-29 03:08:16.047 JupyterHub proxy:299] Checking routes
# hub_1  | [I 2018-06-29 03:08:16.047 JupyterHub proxy:368] Adding default route for Hub: / => http://127.0.0.1:8081
# hub_1  | 03:08:16.050 - info: [ConfigProxy] Adding route / -> http://127.0.0.1:8081
# hub_1  | 03:08:16.053 - info: [ConfigProxy] 201 POST /api/routes/
# hub_1  | [I 2018-06-29 03:08:16.054 JupyterHub app:1895] JupyterHub is now running at http://:8000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-fdeed2f67ec9> in <module>()
# ----> 1 run(["docker-compose", "up"])
#
# <ipython-input-2-cee159ad2c19> in run(args)
#       2     print("Running", "\n\t", " ".join(args))
#       3     proc = subprocess.Popen(args, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
# ----> 4     for line in iter(proc.stdout.readline, b''):
#       5         print(line.decode('utf-8').rstrip())
#
# KeyboardInterrupt:
