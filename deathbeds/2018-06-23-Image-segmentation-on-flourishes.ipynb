# %% [markdown]
# # Image transforms on a flourish

# %%
from numpy import *

# %%
import skimage.io, skimage.transform, skimage.exposure, skimage.morphology, skimage.filters, skimage.feature

# %%
flourish = skimage.io.imread('IMG-0762.JPG')
flat = skimage.color.rgb2gray(flourish)

# %% [markdown]
# # The original drawing.
#
# It was drawn on one of them [big post its]().

# %%
# %matplotlib notebook
skimage.io.imshow(flourish)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib notebook
labelled =  skimage.measure.label(
        flat>.6)
skimage.io.imshow(labelled)
# Out:
# /Users/tonyfast/anaconda/envs/p6/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
# <img src="data:image/png;base64,..." width="432">

# %%
# Out:
# array([[ 0.43604941,  0.44389255,  0.44949569, ...,  0.40520549,
#          0.40882157,  0.40684941],
#        [ 0.69212784,  0.67672431,  0.68064588, ...,  0.40128392,
#          0.40882157,  0.41077098],
#        [ 0.85945451,  0.84937137,  0.83760667, ...,  0.40912706,
#          0.41666471,  0.42253569],
#        ...,
#        [ 0.63494471,  0.63494471,  0.63102314, ...,  0.84676118,
#          0.85068275,  0.85460431],
#        [ 0.63102314,  0.63102314,  0.63102314, ...,  0.84283961,
#          0.84676118,  0.85068275],
#        [ 0.62710157,  0.63102314,  0.63102314, ...,  0.84283961,
#          0.84676118,  0.85068275]])

# %%
from sympy import *

# %%
s = Symbol("A")**2

# %%
from sympy.abc import X,Y,Z

# %%
e = X**2 + Y**2

# %%
init_printing()

# %%
e
# Out:
#  2    2
# X  + Y

# %%
e._assumptions
# Out:
# {'algebraic': None,
#  'antihermitian': None,
#  'commutative': True,
#  'complex': None,
#  'composite': None,
#  'even': None,
#  'finite': None,
#  'hermitian': None,
#  'imaginary': None,
#  'infinite': None,
#  'integer': None,
#  'irrational': None,
#  'negative': None,
#  'noninteger': None,
#  'nonnegative': None,
#  'nonpositive': None,
#  'nonzero': None,
#  'odd': None,
#  'polar': None,
#  'positive': None,
#  'prime': None,
#  'rational': None,
#  'real': None,
#  'transcendental': None,
#  'zero': None}

# %%
lambdify([X, Y], X**2 + Y**2)(10, 20)
# Out:
# 500

# %%
# %matplotlib notebook

skimage.io.imshow(
    (1 - arange(labelled.shape[1])/labelled.shape[1]) * flat + 
    arange(labelled.shape[1])/labelled.shape[1] * labelled/labelled.max())
# Out:
# <img src="data:image/png;base64,..." width="878.4">

# %%
# %matplotlib notebook
skimage.io.imshow(
    skimage.measure.label(
        skimage.color.rgb2gray(flourish)>.6));
# Out:
# /Users/tonyfast/anaconda/envs/p6/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## Skeletonized flourish

# %%
# %matplotlib notebook
skimage.io.imshow(
    skimage.morphology.binary_dilation(
        skimage.morphology.skeletonize(skimage.color.rgb2gray(flourish)>.6), 
        skimage.morphology.disk(5)
    ));
# Out:
# <img src="data:image/png;base64,..." width="825.624987697229">
